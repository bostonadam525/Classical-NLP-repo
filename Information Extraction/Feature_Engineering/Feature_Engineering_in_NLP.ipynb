# %% [markdown]
# # Feature Engineering in NLP
# * Notebook by Adam Lang
# * Date: 7/19/2024
#
# # Overview
# * In this notebook we will go over important techniques to consider when performing feature engineering in NLP.

# %% [markdown]
# ## Feature Engineering Techniques
# 1. Special Characters and Numbers
#   * chars: `@twitter`, `#datascience`
#   * nums: `9897xxxxxx`, phone numbers, etc.
# 2. Word Counts
#   * Sentiment analysis
#      * positive vs. neg text has longer word counts?
#
# 3. Average word length
#    * Document analysis
#    * Example: social media messages vs. legal documents or speeches
#
# 4. Stopwords
#    * Useful in some cases but not all.
#    * Useful: in political speech
#    * Not useful: text classification, named entity recognition
#
# 5. POS tags and NER
#    * Counting POS and NER tags for each feature in a document.
#    * Document Analysis Example, a text may have:
#        * NER = 4
#        * Person = 1
#        * Noun = 5
#        * Verb = 3
#     * This information may be useful in text analytics and developing machine learning models.
#
# 6. .....and others.....
#    * Depends on documents and text you are using.

# %% [markdown]
# # Implementation of Feature Engineering
# * We will demo the following:
# 1. Special characters and numbers
# 2. Word counts
# 3. Number of characters
# 4. Average word length
# 5. Stop words
# 6. POS tags
# 7. NER

# %% [markdown]
# ## Load and preprocess data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## imports
import pandas as pd
import re

# %%
# spacy imports
import spacy
# stopwords spacy
from spacy.lang.en.stop_words import STOP_WORDS

# spacy english language model
nlp = spacy.load('en_core_web_sm')

# %%
## data path
data_path = '/content/drive/MyDrive/Colab Notebooks/Classical NLP/tweets-.csv'

# %%
# upload data -- only first 1000 rows
df = pd.read_csv(data_path, nrows=1000)

# df head
df.head()
# Out:
#                                                 text  favorited  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...      False
# 1  RT @Hemant_80: Did you vote on #Demonetization...      False
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...      False
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...      False
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...      False
#
#    favoriteCount replyToSN              created  truncated  replyToSID  \
# 0              0       NaN  2016-11-23 18:40:30      False         NaN
# 1              0       NaN  2016-11-23 18:40:29      False         NaN
# 2              0       NaN  2016-11-23 18:40:03      False         NaN
# 3              0       NaN  2016-11-23 18:39:59      False         NaN
# 4              0       NaN  2016-11-23 18:39:39      False         NaN
#
#              id  replyToUID  \
# 0  8.014957e+17         NaN
# 1  8.014957e+17         NaN
# 2  8.014955e+17         NaN
# 3  8.014955e+17         NaN
# 4  8.014954e+17         NaN
#
#                                         statusSource       screenName  \
# 0  <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1  <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2  <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3  <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4  <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
#
#    retweetCount  isRetweet  retweeted
# 0           331       True      False
# 1            66       True      False
# 2            12       True      False
# 3           338       True      False
# 4           120       True      False

# %%
# df info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           1000 non-null   object
#  1   favorited      1000 non-null   bool
#  2   favoriteCount  1000 non-null   int64
#  3   replyToSN      104 non-null    object
#  4   created        1000 non-null   object
#  5   truncated      1000 non-null   bool
#  6   replyToSID     73 non-null     float64
#  7   id             1000 non-null   float64
#  8   replyToUID     104 non-null    float64
#  9   statusSource   1000 non-null   object
#  10  screenName     1000 non-null   object
#  11  retweetCount   1000 non-null   int64
#  12  isRetweet      1000 non-null   bool
#  13  retweeted      1000 non-null   bool
# dtypes: bool(4), float64(3), int64(2), object(5)
# memory usage: 82.2+ KB

# %%
#we only need the text column
df.drop(df.columns[1:], axis=1, inplace=True)

# %%
## new df
df.head()
# Out:
#                                                 text
# 0  RT @rssurjewala: Critical question: Was PayTM ...
# 1  RT @Hemant_80: Did you vote on #Demonetization...
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...

# %%
## sample some tweets
df[['text']].sample(5)
# Out:
#                                                   text
# 388  #Demonetization  How does it impact the commo...
# 82   RT ZeeNewsSports: #Demonetization: harbhajan_s...
# 137  The only thing I have gained from Modi's #demo...
# 348  Ts is exactly what Pappu &amp; opposition has ...
# 65   RT @CMOMaharashtra: Watch what @sonunigam thin...

# %%
## example tweet
df.loc[0,'text']
# Out:
# "RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;\x85"

# %%
## another tweet
df.loc[512, 'text']
# Out:
# 'RT @smita_muk: BREAKING NEWS\r\nPMapps result amnounced!\r\n90% Indians support #demonetization\r\n<ed><U+00A0><U+00BD><ed><U+00B1><U+008F><ed><U+00A0><U+00BD><ed><U+00B1><U+008F><ed><U+00A0><U+00BD><ed><U+00B1><U+008F><ed><U+00A0><U+00BD><ed><U+00B1><U+008F><ed><U+00A0><U+00BD><ed><U+00B1><U+008F><ed><U+00A0><U+00BD><ed><U+00B1><U+008F><U+270C><U+270C><U+270C><U+270C><U+270C><U+270C><ed><U+00A0><U+00BD><ed><U+00B1><U+0086><ed><U+00A0><U+00BD><ed><U+00B1><U+0086><ed><U+00A0><U+00BD><ed><U+00B1><U+0086><ed><U+00A0><U+00BD><ed><U+00B1><U+0086><ed><U+00A0><U+00BD><ed><U+00B1><U+0086><ed><U+00A0><U+00BD><ed><U+00B1><U+0086>\r\n@narendramodi Zindabad!'

# %% [markdown]
# Summary:
# * We can see there are unicode chars in the dataset, we will remove these.

# %%
## preprocess tweets
def preprocess(text):

  # replace unicode chars --> empty string
  text = re.sub(r'<U\+[A-Z0-9]+>|<ed>', "", text)
  # remove newline and rawstring chars
  text = re.sub(r'\n|\r', "", text)

  return text

# %%
## applying function
df['text'] = df['text'].apply(preprocess)

# %%
## print result
df.head()
# Out:
#                                                 text
# 0  RT @rssurjewala: Critical question: Was PayTM ...
# 1  RT @Hemant_80: Did you vote on #Demonetization...
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...

# %%
## lets look at 512 again
df.loc[512, 'text']
# Out:
# 'RT @smita_muk: BREAKING NEWSPMapps result amnounced!90% Indians support #demonetization@narendramodi Zindabad!'

# %% [markdown]
# Summary
# * We removed the unicode chars from this tweet and others.

# %%
## shape of df
df.shape
# Out:
# (1000, 1)

# %% [markdown]
# # Extract Text Based Features
#
# ### 1. Special Characters
# * We can use special characters from the tweets to create features.
#
# ### 1.1 Number of mentions in Tweets

# %%
## function to count mentions
def mentions(text):

  # findall mentions
  mentions = re.findall('@\w+', text)

  # return mentions count
  return len(mentions)

# %%
# applying function
df['mentions_count'] = df['text'].apply(mentions)

# %%
# view features
df.head(10)
# Out:
#                                                 text  mentions_count
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0

# %%
df.describe()
# Out:
#        mentions_count
# count     1000.000000
# mean         0.866000
# std          0.988444
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          8.000000

# %% [markdown]
# Summary:
# * We can see the max num of mentions is 8.

# %% [markdown]
# ### 1.2 Number of hashtags used in Tweets

# %%
## function to count hashtags
def hashtags(text):

  # find hashtags
  hashtags = re.findall('#\w+', text)

  # return count of hashtags
  return len(hashtags)

# %%
df.columns
# Out:
# Index(['text', 'mentions_count'], dtype='object')

# %%
# apply function
df['hashtags_count'] = df['text'].apply(hashtags)

# %%
## result
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count
# 0               1
# 1               1
# 2               1
# 3               1
# 4               2
# 5               2
# 6               1
# 7               2
# 8               1
# 9               1

# %%
## stats on hashtags
df['hashtags_count'].describe()
# Out:
# count    1000.000000
# mean        1.688000
# std         1.272114
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        10.000000
# Name: hashtags_count, dtype: float64

# %% [markdown]
# Summary:
# * Max num of hashtags in 1 tweet is 10.

# %% [markdown]
# ### 1.3 Number of name titles in Tweet

# %%
# function to count name titles in Tweet
def title(text):
  count = re.findall('Mr\.|Mrs\.|Dr\.|Miss\s*', text)
  return len(count)

# %%
# apply
df['text'].apply(title)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: text, Length: 1000, dtype: int64

# %% [markdown]
# Summary:
# * It appears surnames are not used often in tweets.

# %% [markdown]
# ### 2.1 Word Count

# %%
# list comp to count num of words in tweet
df['word_count'] = [len(i.split()) for i in df['text']]

# %%
## features
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count
# 0               1          20
# 1               1          11
# 2               1          21
# 3               1          16
# 4               2           9
# 5               2          12
# 6               1          22
# 7               2          18
# 8               1          17
# 9               1          18

# %%
## describe stats
df['word_count'].describe()
# Out:
# count    1000.000000
# mean       16.685000
# std         4.566468
# min         3.000000
# 25%        14.000000
# 50%        17.000000
# 75%        20.000000
# max        28.000000
# Name: word_count, dtype: float64

# %% [markdown]
# Summary:
# * The max number of words in a tweet is 28.
# * The average number of words in a tweet is 16-17.

# %% [markdown]
# ### 2.2 Number of Chars

# %%
## list comprehension count num of chars
df['char_count'] = [len(i) for i in df['text']]

# %%
# print features
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count  char_count
# 0               1          20         144
# 1               1          11          66
# 2               1          21         138
# 3               1          16         140
# 4               2           9         107
# 5               2          12         121
# 6               1          22         143
# 7               2          18         139
# 8               1          17         139
# 9               1          18         140

# %%
# describe
df['char_count'].describe()
# Out:
# count    1000.000000
# mean      124.673000
# std        21.427861
# min        34.000000
# 25%       117.000000
# 50%       135.000000
# 75%       139.000000
# max       148.000000
# Name: char_count, dtype: float64

# %% [markdown]
# Summary: Max num of chars in a tweet is 148 with an avg of 124. We should note that we are counting spaces too.

# %% [markdown]
# ### 3. Average Word Length

# %%
# function to calculate avg word length of tweet
def avg_word_len(text):

  # store word lengths
  word_len = 0

  # iterate over tweets
  for token in text.split():
    word_len += len(token)

  # num of words in tweet
  word_count = text.split()

  # return avg len of words in tweet
  return round((word_len/len(word_count)),3)

# %%
# apply function
df['avg_word_len'] = df['text'].apply(avg_word_len)

# %%
# print features
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count  char_count  avg_word_len
# 0               1          20         144         6.200
# 1               1          11          66         5.091
# 2               1          21         138         5.571
# 3               1          16         140         7.750
# 4               2           9         107        11.000
# 5               2          12         121         9.167
# 6               1          22         143         5.500
# 7               2          18         139         6.722
# 8               1          17         139         7.176
# 9               1          18         140         6.778

# %%
# describe
df['avg_word_len'].describe()
# Out:
# count    1000.00000
# mean        6.86535
# std         1.69860
# min         3.89300
# 25%         5.65000
# 50%         6.57900
# 75%         7.64900
# max        16.66700
# Name: avg_word_len, dtype: float64

# %% [markdown]
# Summary: Avg word len max is 16, mean is 6.

# %% [markdown]
# ### 4. Stopwords

# %%
# function to count num of stopwords in tweets
def stopwords(text):

  # create spacy object
  doc = nlp(text)

  # var to store count of stopwords
  count = 0
  for token in doc:
    if token.is_stop == True:
      count += 1
  return count

# %%
# applying function
df['stopwords'] = df['text'].apply(stopwords)

# %%
# describe
df['stopwords'].describe()
# Out:
# count    1000.000000
# mean        6.038000
# std         3.285019
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%         8.000000
# max        19.000000
# Name: stopwords, dtype: float64

# %% [markdown]
# Summary:
# * The max num of stopwords is 19, the avg is 6.

# %% [markdown]
# ### 5. POS tagging

# %%
## creating function using spacy for POS
def pos(text):

  # spacy object
  doc = nlp(text)

  # var store count of POS tags
  count = 0

  # iterate over tokens
  for token in doc:
    # count noun, preposition, adjective, verb
    if token.pos_ in ['NOUN', 'ADP', 'ADJ', 'VBG']:
      count += 1

  # return the count
  return count

# %%
# apply func
df['POS'] = df['text'].apply(pos)

# %%
# head of df
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count  char_count  avg_word_len  stopwords  POS
# 0               1          20         144         6.200          7    9
# 1               1          11          66         5.091          4    4
# 2               1          21         138         5.571          5    6
# 3               1          16         140         7.750          2   10
# 4               2           9         107        11.000          0    6
# 5               2          12         121         9.167          4    6
# 6               1          22         143         5.500         11   11
# 7               2          18         139         6.722          8    7
# 8               1          17         139         7.176          8   10
# 9               1          18         140         6.778          7   10

# %%
# describe result
df['POS'].describe()
# Out:
# count    1000.000000
# mean        7.657000
# std         3.096601
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        10.000000
# max        19.000000
# Name: POS, dtype: float64

# %% [markdown]
# ### 6. NER

# %%
# function for NER count
def ner(text) -> int:

  # spacy obj
  doc = nlp(text)

  # var count store NER tags
  count = 0

  # iterate tokens using spacy doc.ents
  for ent in doc.ents:
    # increment counter if token is a NER
    if ent.label_:
      count += 1
  # return count
  return count

# %%
# apply function
df['NER'] = df['text'].apply(ner)

# %%
# result
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count  char_count  avg_word_len  stopwords  POS  NER
# 0               1          20         144         6.200          7    9    3
# 1               1          11          66         5.091          4    4    1
# 2               1          21         138         5.571          5    6    4
# 3               1          16         140         7.750          2   10    1
# 4               2           9         107        11.000          0    6    2
# 5               2          12         121         9.167          4    6    2
# 6               1          22         143         5.500         11   11    3
# 7               2          18         139         6.722          8    7    2
# 8               1          17         139         7.176          8   10    1
# 9               1          18         140         6.778          7   10    3

# %%
# describe NERs
df['NER'].describe()
# Out:
# count    1000.000000
# mean        2.269000
# std         1.464508
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000
# Name: NER, dtype: float64

# %%
##  getting the NER labels
def ner_label(text_):

  # spacy obj
  doc = nlp(text_)

  # empty list
  ent_var = []

  # iterate
  for ent in doc.ents:
    assert ent.text, ent.label_
    ent_var.append([ent.text, ent.label_])


  return dict(ent_var)

# %%
# apply func
df['ner_label'] = df['text'].apply(ner_label)

# %%
df.head(10)
# Out:
#                                                 text  mentions_count  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...               1
# 1  RT @Hemant_80: Did you vote on #Demonetization...               1
# 2  RT @roshankar: Former FinSec, RBI Dy Governor,...               1
# 3  RT @ANI_news: Gurugram (Haryana): Post office ...               1
# 4  RT @satishacharya: Reddy Wedding! @mail_today ...               2
# 5  @DerekScissors1: Indias #demonetization: #Bla...               2
# 6  RT @gauravcsawant: Rs 40 lakh looted from a ba...               1
# 7  RT @Joydeep_911: Calling all Nationalists to j...               1
# 8  RT @sumitbhati2002: Many opposition leaders ar...               2
# 9  National reform now destroyed even the essence...               0
#
#    hashtags_count  word_count  char_count  avg_word_len  stopwords  POS  NER  \
# 0               1          20         144         6.200          7    9    3
# 1               1          11          66         5.091          4    4    1
# 2               1          21         138         5.571          5    6    4
# 3               1          16         140         7.750          2   10    1
# 4               2           9         107        11.000          0    6    2
# 5               2          12         121         9.167          4    6    2
# 6               1          22         143         5.500         11   11    3
# 7               2          18         139         6.722          8    7    2
# 8               1          17         139         7.176          8   10    1
# 9               1          18         140         6.778          7   10    3
#
#                                            ner_label
# 0  {'RT': 'GPE', 'PayTM': 'PERSON', 'about #Demon...
# 1                       {'#Demonetization': 'MONEY'}
# 2  {'FinSec': 'ORG', 'RBI': 'ORG', 'CBDT Chair + ...
# 3                             {'Gurugram': 'PERSON'}
# 4           {'@mail_today': 'DATE', '#': 'CARDINAL'}
# 5          {'#': 'CARDINAL', 'Blackmoney': 'PERSON'}
# 6  {'Rs 40': 'PRODUCT', 'Kishtwar': 'GPE', 'Third...
# 7  {'RT @Joydeep_911': 'ORG', 'Nationalists': 'NO...
# 8                      {'RT @sumitbhati2002': 'ORG'}
# 9  {'#': 'CARDINAL', 'second': 'ORDINAL', 'https:...

# %%
# iterate through column 'ner_label' and extract keys and value counts

from collections import defaultdict

key_counts = defaultdict(int)
value_counts = defaultdict(int)

for _, row in df.iterrows():
  for key, value in row['ner_label'].items():
    key_counts[key] += 1
    value_counts[value] += 1

print("Key counts:", key_counts)
print("Value counts:", value_counts)
# Out:
# Key counts: defaultdict(<class 'int'>, {'RT': 5, 'PayTM': 2, 'about #Demonetization': 2, '#Demonetization': 77, 'FinSec': 2, 'RBI': 10, 'CBDT Chair + Harvard': 2, 'Aam Aadmi': 4, 'Gurugram': 1, '@mail_today': 1, '#': 288, 'Blackmoney': 1, 'Rs 40': 1, 'Kishtwar': 1, 'Third': 1, 'RT @Joydeep_911': 1, 'Nationalists': 2, 'RT @sumitbhati2002': 1, 'second': 1, 'https://t.co/eyySIREiUq': 1, 'Narendra Modi App': 1, '@Jaggesh2 Bharat': 1, 'RT @sona2905': 1, 'RT @Dipankar_cpiml: The Modi app': 1, 'Gandhi': 3, 'Kerala': 2, 'RT @AAPVind:': 1, '@naam_pk': 2, "about #NarendraModi's": 5, '100%': 4, '#survey@DonMu': 1, 'first': 11, 'RT @mayankjain100': 1, 'Communal and Black Money is Secular': 2, 'LOL': 3, '#Demonetization Effect': 1, 'https://t.co/aA5lfy9ALG': 1, 'RT roshankar': 4, 'Harvard': 6, 'Larry Summers': 6, '@arunjaitley': 4, 'Lrnd': 1, '2sales': 1, 'BAU Operations #Demonetization': 1, 'RT @kanimozhi:': 4, 'Pappu &': 2, '12.5': 1, '#DeMonetization': 7, 'Card': 1, 'Amex': 1, 'RT @harshkkapoor:': 2, '24': 6, 'Blackmoney@na': 1, 'RT @rohanmlw': 1, '@PMOIndia on #Demonetization': 2, '5': 7, '90%': 2, 'ModiSarkar': 1, '#demonetization': 29, 'NETAS': 1, '#CashlessCorruption &': 1, 'Section 144': 1, 'District Magistrate': 1, 'West Bengal': 1, 'Y Pawar U-turned': 1, 'MUDRA': 3, 'R Vaidyanathan': 3, 'Modi': 18, 'Move Across': 7, '80-86%': 6, 'dra': 1, 'https://t.co/DuvbMtEi1Y': 1, 'one': 7, 'Congress': 6, 'Doordarshan': 1, 'Sri S.Gurumurthy https://t.co/LdeBCADAeR': 1, '2': 11, 'India': 45, 'Ji': 2, '@timesofindia': 2, 'Delhi': 6, 'https://t.co/vv9qtRqqSI': 1, '90 %': 1, '15 days': 2, '4': 6, 'RT @ashu3page': 2, 'Gujarat': 2, 'nitishkumar': 1, 'PM': 4, '33000 thousand': 1, 'Smt': 1, 'Arundhati Bhattacharya': 1, 'Jantar-Mantar': 1, '13th day': 1, '@PMOIndia': 9, '@TruthOfGujarat': 1, 'season': 1, 'Farmers': 1, '#Demonetizationhttps://t.co/0kq8BsJ1iSWhen PM': 1, 'RT @CMOMaharashtra': 3, 'RT @ShashiTharoor:': 1, '@anandkamal Frankly': 1, 'Parlmnt': 2, 'blackmoney': 2, '1.9%': 1, 'netascashin https://t.co/rqjsdiGvcG': 1, 'Chanda Kochar': 1, 'MD': 2, '#demonetization https://t': 1, 'RT @karnataka_ioc:': 1, 'Mini': 2, 'Hinterland': 2, 'DEA': 5, 'this morning': 5, 'https://t.co': 4, 'GPS': 1, '2000': 4, '#Modo': 1, 'Looks Ambit Capital': 1, 'the governemnt big #': 3, 'BlackMoney': 11, '#demonetization #': 5, '#Demonetization &': 1, 'PM Modihttps://t.co/SLJoymBy1': 1, 'Opposition': 6, '#demonetization &': 7, 'Parliame': 1, 'RT @YSRCParty': 3, 'Days': 4, '@ncbn': 2, 'Heritage': 4, 'RTGS': 1, '6:30 PM': 1, '24th November, 2016': 1, 'https://t.co/TaCfmKF3Cs': 1, 'no PM Modi': 1, 'RT @IndiaFactsOrg': 1, 'The Ultimate Weapon against Black': 4, '@IndiaFactsOrg': 2, 'More than 700': 1, 'Kolkata': 4, 'zero': 1, 'Naveen Patnaik': 1, 'Chandrababu Naidu': 1, 'BBC': 2, 'NDTV': 1, 'Housewife': 1, '@suryanavin MD ItzCash': 2, '14000': 2, 'Sonia Gandhi': 1, 'RT @JasBJP': 1, '@MamtaOfficiaI': 1, 'RT @sandipsabharwal': 2, '#DemonetizationPl': 2, 'RT @JLLIndia:': 1, "#Demonetization's": 1, '#India #': 5, 'Pankaj Renjhen': 2, 'Rubbishing #Demonetization': 1, 'Brownie Points': 1, 'Indian': 18, '2nd': 2, 'Kejri': 2, 'Mamta': 3, '#VishalJanSabha #KhulkeDulke #Ind': 1, 'Today': 6, '200': 5, '125': 2, 'Parliament': 9, '2day': 2, '#__': 5, 'RT @tweepul': 1, 'white money &amp': 2, 'Dust': 1, 'TMC': 8, 'Mamta App': 1, 'Cousin': 1, '27': 1, 'today': 17, '6 months': 1, 'more bhakt': 1, '#entire #': 1, '#NotADefaulter #PMModi #NotProCongress': 1, 'maid': 1, '15': 2, 'blackswan': 1, 'https://t.co/cVUn1WF4IS': 1, '8': 5, '#smart #': 1, 'now!https://t.co/pwVrLD6tSgvia': 1, 'Pokhran': 1, 'Oscar': 2, 'Rich': 1, 'clinton': 1, '#Modi': 3, 'SouthAsia': 2, '#BJP': 2, '55': 1, 'the perks &amp': 1, 'MLA': 1, '50%': 2, 'Hindi': 1, 'RT @FTIIndia': 1, 'Real Estate, Consumption, Banks': 2, 'RT @FTIIndia:': 2, '@muglikar': 2, 'APP': 2, 'Please': 1, '#Demonetization #IndiaFightsCorruption Immense': 1, 'RT @RealZaidHamid': 1, '20 km': 1, 'Ravi Shankar': 1, 'https://t.co/GV5gt4sjLW': 1, 'Home': 1,  ...
# Value counts: defaultdict(<class 'int'>, {'GPE': 173, 'PERSON': 341, 'MONEY': 331, 'ORG': 602, 'DATE': 105, 'CARDINAL': 458, 'PRODUCT': 15, 'ORDINAL': 16, 'NORP': 59, 'PERCENT': 63, 'LOC': 9, 'LAW': 2, 'TIME': 23, 'QUANTITY': 4, 'EVENT': 5, 'WORK_OF_ART': 14, 'FAC': 4})
